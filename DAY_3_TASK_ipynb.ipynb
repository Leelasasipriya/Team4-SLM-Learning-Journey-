# %% [markdown]
# <a href="https://colab.research.google.com/github/Leelasasipriya/Team4-SLM-Learning-Journey-/blob/main/DAY_3_TASK_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def multiplication_table(num):
    for i in range (1,6):
        print(f"{num} x {i} = {num*i}")
num = int(input("Enter number: "))
multiplication_table(num)
# Out:
# Enter number: 45
# 45 x 1 = 45
# 45 x 2 = 90
# 45 x 3 = 135
# 45 x 4 = 180
# 45 x 5 = 225

# %%
d_s = []
d_s.append("python")
d_s.append("java")
d_s.append("c")

print("stored data:",d_s)
# Out:
# stored data: ['python', 'java', 'c']

# %%
students = []

students.append("leela")
students.append("sasi")
students.append("priya")

print("stds list:",students)
# Out:
# stds list: ['leela', 'sasi', 'priya']

# %%
students = []
n = int(input("Enter number of students: "))
for i in range(n):
    name = input("Enter student name: ")
    students.append(name)
print("stds list:",students)
# Out:
# Enter number of students: 3
# Enter student name: leela
# Enter student name: sasi
# Enter student name: priya
# stds list: ['leela', 'sasi', 'priya']

# %%
stds = ["leela","sasi","priya"]
for student in students:
  print(student)
# Out:
# leela
# sasi
# priya

# %%
def add_nums(a,b):
 return a+b
n1 = 45
n2 = 54
result = add_nums(n1,n2)
print("sum=",n1+n2)
# Out:
# sum= 99
